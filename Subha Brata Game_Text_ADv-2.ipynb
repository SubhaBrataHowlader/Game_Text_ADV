# %%
#comment Movie "SKYFALL"
#The Movie based on investigation of MI6 which is bond going to find:


print("""A) Introduction :\n
 
    This game is based on the spy movie SKYFALL(2012). It consists of four 
    stages, and also has defined functions for start a mission, investigate
    as a agents, win, and lose. This game based on a MI6 agent, and how he 
    sucessfully excute the mission.
    
    Round 1: Decide how to stolen a hard draive.
    Round 2: Investigate as a agent.
    Round 3: Defeat and execute work.
    Round 4: Mission accomplished.""")
    

#Going to start the section with the movie where he is playing as a spy

from sys import exit
import random

def start():
    print("""
         As Bond start his journey, He saw a train in the distance. 
         He needs to cross over a sea. And if cross it in order to continue his journey and catch M.
         """)
    input("<Press enter to continue>\n").lower()
    
#In this path it's discussed if he is willing to to the investigation or decide letter:
    
def starting_path():
    print("""
    As the spy of the movie, what would you like to do?
    1) Start this new investigation.
    2) Not interest in this job.
    3) decide later!
    """)
    
    choice = input(">  \n").lower()

    if "1" in choice or "Start this new investigation" in choice or "new investigation" in choice:
        print("\nStart this new investigation!\n")
        input("<Press enter to continue>\n").lower()
    
    elif "2" in choice or "rest" in choice or "later" in choice:
        print("""\nGo home & have food!""")
        exit(0)
        
    
    elif "3" in choice or "run" in choice:
        print("\nWell I guess the quest is over. Good-bye!")
        exit(0)
    
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n").lower()
        
#Here movie going to next level, where he wants to cross the rever by Boat or something else

def in_train():
    print("""
As you're about to start crossover the Sea, a police saw you and trying to shoot:
              
              "STOP. If he want to cross the Sea he must answer me
              these four questions, ere the other side he see." 
              
              "what do you want to do?\n"
              "[1]cross river by boat\n"
              "[2] cross river by swimming\n"
              "[3] don't cross the river...Run!\n"
              
         """)
    
#He decide what he is going to do, and after that he can go for next step    
    
    question=input("what to do?: ").lower()
    
    if question == "1":
        print("You can input anything and you're ok.")
        name = input("Your name: \n").lower()
        print(f"Bond: Nice to meet you {name}!")
        
        
    elif question == "2":
        print("1) I am trying to find hardware")
        print("2) I am NOT interested.")
        print("3) I Quit.")
            
        quest = input("> \n").lower()
        quest = quest.lower()    
        if quest == '1':
                print("Thanks for letting me know. It's kind of lonely guarding this bridge all the time.\n")
                questions -=1
            
        else: 
                print("You go home & have food.")
                fail()

    elif question == "3":
        print("I Quit.\n")
        
            
        if 'red' in gun or 'AK47' in color or 'AK56' in color:
                print("Bond: Where is MI6?\n")
                questions -=1
            
        else:
                print("Bond: What? That's not your gun!")
                print("You fly high into the air and over sea.\n")
                fail()
## a serial number is assigned to the used going from 100 to 1000

def new_chapter():
    Bonus=random.randint(100,1000)

    print(f"congratulations, you got {Bonus} dollars... see you in some time!!")
    print("1) Keep silent until the Bond is here.")
    print("2) Try to walk.\n")
    guess = input("> \n").lower()
    if '1' in guess or 'silent' in guess or 'walk' in guess:
        print("Bond: Where is MI6?\n")
        
    elif '2' in guess or 'try' in guess or 'guess' in guess: 
        input("Your guess: \n").lower()
        print("Bond: Ha! I made that place up!")
                 
            
       
    else:            
        print("Investigate it again!\n")
        input("<Press enter to continue>\n").lower()
        fail()
        
#Here Bond started to go by train and how he faced the situation in train.

def James_007():
    print("""
Now Bond is in train, he is going to scerch for MI6. He got a information that MI6 have thrown away from train.
""")
    print("What do you do?")
    print("1) Attack with your gun?")
    print("2) Jump from train?")
    print("3) Sit & think!")
    
    gun = input("> \n").lower()
    
    if '1' in gun:
        print("You attack with gun and started firings.")
        print("Bond jump and runs away.\n")
        input("<Press enter to continue>\n")
        grail()
    
    elif '2' in gun:
        print('You end up back at the bridge.')
        
## a serial number is assigned to the used going from 100 to 1000

def grail():
    value=random.randint(100,1000)

    print(f"congratulations, you won {value} dollars... see you next time!!")


    input("<Press enter to exit, you champion!>\n").lower()

#The game is going to end over here, Bond received some doller here and game end

    exit(0)
    
def fail():
    print('\nYou have failed in Investigation.')
    input('<Game Over>').lower()
    exit(0)
#This is the final stage and game finished.

start()
starting_path()
in_train()
new_chapter()
James_007()
# Out:
# A) Introduction :
#
#
#     This game is based on the spy movie SKYFALL(2012). It consists of four
#     stages, and also has defined functions for start a mission, investigate
#     as a agents, win, and lose. This game based on a MI6 agent, and how he
#     sucessfully excute the mission.
#
#     Round 1: Decide how to stolen a hard draive.
#     Round 2: Investigate as a agent.
#     Round 3: Defeat and execute work.
#     Round 4: Mission accomplished.
#
#          As Bond start his journey, He saw a train in the distance.
#          He needs to cross over a sea. And if cross it in order to continue his journey and catch M.
#
# <Press enter to continue>
#
#
#     As the spy of the movie, what would you like to do?
#     1) Start this new investigation.
#     2) Not interest in this job.
#     3) decide later!
#
# >
# 1
#
# Start this new investigation!
#
# <Press enter to continue>
#
#
# As you're about to start crossover the Sea, a police saw you and trying to shoot:
#
# ...
